# %%
import cv2
import os
import csv
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\91708\Desktop\empty.csv")
df
# Out:
#    Id     Name 06-09-2002
# 0  22  Aashish          P
# 1   2  aashish        NaN
# 2   3      HHH          P
# 3   4    rahsi        NaN
# 4   5    mashi        NaN

# %% [markdown]
# # Capture face Photos for training image

# %%
# In this code it takes input as name and id and after that by OpenCv cam we capture 100 image for training of image.
# When image is saving it also carry name and their Id save it in directiory.


def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        pass

    try:
        import unicodedata
        unicodedata.numeric(s)
        return True
    except (TypeError, ValueError):
        pass

    return False



Id = input("Enter Your Id: ")
name = input("Enter Your Name: ")

if(is_number(Id) and name.isalpha()):
    cam = cv2.VideoCapture(0)
    harcascadePath = r'C:/Users/91708/Desktop/harra/haarcascade_frontalface_default.xml'
    detector = cv2.CascadeClassifier(harcascadePath)
    sampleNum = 0
    while(True):
        ret, img = cam.read()
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        faces = detector.detectMultiScale(gray, 1.3, 5, minSize=(30,30),flags = cv2.CASCADE_SCALE_IMAGE)
        for(x,y,w,h) in faces:
            cv2.rectangle(img, (x, y), (x+w, y+h), (10, 159, 255), 2)
            #incrementing sample number
            sampleNum = sampleNum+1
            #saving the captured face in the dataset folder TrainingImage
            cv2.imwrite("C:/Users/91708/Desktop/Training" + os.sep +name + "."+Id + '.' +
                        str(sampleNum) + ".jpg", gray[y:y+h, x:x+w])
            #display the frame
            cv2.imshow('frame', img)
        #wait for 100 miliseconds
        if cv2.waitKey(100) & 0xFF == ord('q'):
            break
        # break if the sample number is more than 100
        elif sampleNum > 100:
            break
    cam.release()
    cv2.destroyAllWindows()

    

    
    res = "Images Saved for ID : " + Id + " Name : " + name
    row = [Id, name]
    # with open("StudentDetails"+os.sep+"StudentDetails.csv", 'a+') as csvFile:
    #     writer = csv.writer(csvFile)
    #     writer.writerow(row)
        
    # csvFile.close()
else:
    if(is_number(Id)):
        print("Enter Alphabetical Name")
    if(name.isalpha()):
        print("Enter Numeric ID")
# Out:
# Enter Your Id:  3
# Enter Your Name:  HHH

# %% [markdown]
# # Here we train image with OpenCV

# %%
import numpy as np # train file
from PIL import Image
recognizer=cv2.face.LBPHFaceRecognizer_create()
path=r'C:\Users\91708\Desktop\Training'

def getImagesWithID(path):
    imagePaths=[os.path.join(path,f) for f in os.listdir(path)]
    faces=[]
    IDs=[]
    for imagePath in imagePaths:
        faceImg=Image.open(imagePath).convert('L')
        faceNp=np.array(faceImg,'uint8')
        ID=int(os.path.split(imagePath)[1].split('.')[1])
        faces.append(faceNp)
        IDs.append(ID)
    
        cv2.imshow("training",faceNp)
        cv2.waitKey(100) # for 10 milliseconds wait......
    return np.array(IDs), faces
    
Ids, faces=getImagesWithID(path)
recognizer.train(faces,np.array(Ids))
recognizer.save(r"C:\Users\91708\Desktop\trainningData.yml")
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import pandas as pd
date="06-09-2002"
faceDetect = cv2.CascadeClassifier(r'C:/Users/91708/Desktop/harra/haarcascade_frontalface_default.xml')
cam = cv2.VideoCapture(0)
rec = cv2.face.LBPHFaceRecognizer_create()
rec.read(r"C:\Users\91708\Desktop\trainningData.yml")
id = 0
font = cv2.FONT_HERSHEY_COMPLEX_SMALL

df=pd.read_csv(r"C:\Users\91708\Desktop\empty.csv")

while (True):

    ret, img = cam.read()
    gray = cv2.cvtColor(img, cv2.COLOR_BGRA2GRAY)
    faces = faceDetect.detectMultiScale(gray, 2, 4)
    for (x, y, w, h) in faces:
        # threshold=48
        
        id, conf = rec.predict(gray[y:y + h, x:x + w])
        # print(conf)
        # if conf>threshold:
        #     color=(0, 255, 0)
        # else:
        #     color=(255, 0, 0)
        # t="Unknown"
        color=(255, 0, 0)
        id1 = df['Name'][df.Id==id].values[0]
       

            
        cv2.rectangle(img, (x, y), (x + w, y + h), color, 4)

        df[date][df.Id==id]='P'
        df.to_csv(r"C:\Users\91708\Desktop\empty.csv",index=False)
        # cv2.putText(img, str(id1), (x, y+h ), font, 1, color)

        # if conf>threshold:
        #     cv2.putText(img, str(id1), (x, y ), font, 1, color)

        # else:
            
        cv2.putText(img, id1, (x, y ), font, 1, color)

            
            
        
        
    cv2.imshow("Face", img)
    if (cv2.waitKey(1) & 0xFF == ord('q')):
        break

cam.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\91708\AppData\Local\Temp\ipykernel_2472\3235605249.py:36: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[date][df.Id==id]='P'
# ...

# %%
df
# Out:
#    Id     Name 06-09-2002
# 0  22  Aashish          P
# 1   2  aashish        NaN
# 2   3      HHH          P
# 3   4    rahsi        NaN
# 4   5    mashi        NaN

# %%
You can see it update automatically
# Out:
# []
